# %%
import datetime as dt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pizza_types=pd.read_csv("C:/Users/MMC/Desktop/excel files/pizza_types.csv",encoding="unicode escape")
pizza_types
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
pizzas=pd.read_csv("C:/Users/MMC/Desktop/excel files/pizzas.csv",encoding="unicode escape")
pizzas
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
orders=pd.read_csv("C:/Users/MMC/Desktop/excel files/orders.csv",encoding="unicode escape")
orders["date"] = pd.to_datetime(orders["date"])
orders["time"] = pd.to_datetime(orders["time"])
orders["weekday"] =orders["date"].dt.strftime("%A")
orders["month"] =orders["date"].dt.strftime("%B")
orders["year"] =orders["date"].dt.strftime("%Y")
orders["hour"] =orders["time"].dt.strftime("%H")
orders["hour"] = orders["hour"].astype("int")


orders
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_19656\1741885981.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   orders["time"] = pd.to_datetime(orders["time"])
#        order_id       date                time   weekday     month  year  hour
# 0             1 2015-01-01 2024-04-15 11:38:36  Thursday   January  2015    11
# 1             2 2015-01-01 2024-04-15 11:57:40  Thursday   January  2015    11
# 2             3 2015-01-01 2024-04-15 12:12:28  Thursday   January  2015    12
# 3             4 2015-01-01 2024-04-15 12:16:31  Thursday   January  2015    12
# 4             5 2015-01-01 2024-04-15 12:21:30  Thursday   January  2015    12
# ...         ...        ...                 ...       ...       ...   ...   ...
# 21345     21346 2015-12-31 2024-04-15 20:51:07  Thursday  December  2015    20
# ...

# %%
order_details=pd.read_csv("C:/Users/MMC/Desktop/excel files/order_details.csv",encoding="unicode escape")
order_details
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %% [markdown]
# # Inspection

# %%
                                            #merge
df =pd.merge(left = order_details, right = pizzas, on = "pizza_id", how = "left" )
df
# Out:
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# 2                     3         2  five_cheese_l         1   five_cheese    L
# 3                     4         2    ital_supr_l         1     ital_supr    L
# 4                     5         2     mexicana_m         1      mexicana    M
# ...                 ...       ...            ...       ...           ...  ...
# 48615             48616     21348  ckn_alfredo_m         1   ckn_alfredo    M
# 48616             48617     21348  four_cheese_l         1   four_cheese    L
# 48617             48618     21348   napolitana_s         1    napolitana    S
# 48618             48619     21349     mexicana_l         1      mexicana    L
# 48619             48620     21350      bbq_ckn_s         1       bbq_ckn    S
#
#        price
# 0      13.25
# ...

# %%
df =pd.merge(left = df, right = pizza_types, on = "pizza_type_id", how = "left" )
df
# Out:
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# 2                     3         2  five_cheese_l         1   five_cheese    L
# 3                     4         2    ital_supr_l         1     ital_supr    L
# 4                     5         2     mexicana_m         1      mexicana    M
# ...                 ...       ...            ...       ...           ...  ...
# 48615             48616     21348  ckn_alfredo_m         1   ckn_alfredo    M
# 48616             48617     21348  four_cheese_l         1   four_cheese    L
# 48617             48618     21348   napolitana_s         1    napolitana    S
# 48618             48619     21349     mexicana_l         1      mexicana    L
# 48619             48620     21350      bbq_ckn_s         1       bbq_ckn    S
#
# ...

# %%
df.describe()
df
# Out:
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# 2                     3         2  five_cheese_l         1   five_cheese    L
# 3                     4         2    ital_supr_l         1     ital_supr    L
# 4                     5         2     mexicana_m         1      mexicana    M
# ...                 ...       ...            ...       ...           ...  ...
# 48615             48616     21348  ckn_alfredo_m         1   ckn_alfredo    M
# 48616             48617     21348  four_cheese_l         1   four_cheese    L
# 48617             48618     21348   napolitana_s         1    napolitana    S
# 48618             48619     21349     mexicana_l         1      mexicana    L
# 48619             48620     21350      bbq_ckn_s         1       bbq_ckn    S
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# order_details_id    0
# order_id            0
# pizza_id            0
# quantity            0
# pizza_type_id       0
# size                0
# price               0
# name                0
# category            0
# ingredients         0
# dtype: int64

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   pizza_type_id     48620 non-null  object
#  5   size              48620 non-null  object
#  6   price             48620 non-null  float64
#  7   name              48620 non-null  object
#  8   category          48620 non-null  object
#  9   ingredients       48620 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 3.7+ MB
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# ...

# %% [markdown]
# # cleaning

# %%
df["price"].astype(int)
df
# Out:
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# 2                     3         2  five_cheese_l         1   five_cheese    L
# 3                     4         2    ital_supr_l         1     ital_supr    L
# 4                     5         2     mexicana_m         1      mexicana    M
# ...                 ...       ...            ...       ...           ...  ...
# 48615             48616     21348  ckn_alfredo_m         1   ckn_alfredo    M
# 48616             48617     21348  four_cheese_l         1   four_cheese    L
# 48617             48618     21348   napolitana_s         1    napolitana    S
# 48618             48619     21349     mexicana_l         1      mexicana    L
# 48619             48620     21350      bbq_ckn_s         1       bbq_ckn    S
#
# ...

# %%
df["total sale"]=df["quantity"]*df["price"]
df
# Out:
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# 2                     3         2  five_cheese_l         1   five_cheese    L
# 3                     4         2    ital_supr_l         1     ital_supr    L
# 4                     5         2     mexicana_m         1      mexicana    M
# ...                 ...       ...            ...       ...           ...  ...
# 48615             48616     21348  ckn_alfredo_m         1   ckn_alfredo    M
# 48616             48617     21348  four_cheese_l         1   four_cheese    L
# 48617             48618     21348   napolitana_s         1    napolitana    S
# 48618             48619     21349     mexicana_l         1      mexicana    L
# 48619             48620     21350      bbq_ckn_s         1       bbq_ckn    S
#
# ...

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   pizza_type_id     48620 non-null  object
#  5   size              48620 non-null  object
#  6   price             48620 non-null  float64
#  7   name              48620 non-null  object
#  8   category          48620 non-null  object
#  9   ingredients       48620 non-null  object
#  10  total sale        48620 non-null  float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 4.1+ MB
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# ...

# %%
df["total sale"]=df["total sale"].astype(int)
df
# Out:
#        order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                     1         1     hawaiian_m         1      hawaiian    M
# 1                     2         2  classic_dlx_m         1   classic_dlx    M
# 2                     3         2  five_cheese_l         1   five_cheese    L
# 3                     4         2    ital_supr_l         1     ital_supr    L
# 4                     5         2     mexicana_m         1      mexicana    M
# ...                 ...       ...            ...       ...           ...  ...
# 48615             48616     21348  ckn_alfredo_m         1   ckn_alfredo    M
# 48616             48617     21348  four_cheese_l         1   four_cheese    L
# 48617             48618     21348   napolitana_s         1    napolitana    S
# 48618             48619     21349     mexicana_l         1      mexicana    L
# 48619             48620     21350      bbq_ckn_s         1       bbq_ckn    S
#
# ...

# %% [markdown]
# # 1. total sales

# %%
df["total sale"].sum()
# Out:
# 795820

# %% [markdown]
# # The total pizza sale is $2873106

# %%
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                 1         1     hawaiian_m         1      hawaiian    M
# 1                 2         2  classic_dlx_m         1   classic_dlx    M
# 2                 3         2  five_cheese_l         1   five_cheese    L
# 3                 4         2    ital_supr_l         1     ital_supr    L
# 4                 5         2     mexicana_m         1      mexicana    M
#
#    price                       name category  \
# 0  13.25         The Hawaiian Pizza  Classic
# 1  16.00   The Classic Deluxe Pizza  Classic
# 2  18.50      The Five Cheese Pizza   Veggie
# 3  20.75  The Italian Supreme Pizza  Supreme
# 4  16.00         The Mexicana Pizza   Veggie
#
#                                          ingredients  total sale
# 0           Sliced Ham, Pineapple, Mozzarella Cheese          13
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...          16
# ...

# %% [markdown]
# # 2. identify which pizza is ordered the most

# %%
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity pizza_type_id size  \
# 0                 1         1     hawaiian_m         1      hawaiian    M
# 1                 2         2  classic_dlx_m         1   classic_dlx    M
# 2                 3         2  five_cheese_l         1   five_cheese    L
# 3                 4         2    ital_supr_l         1     ital_supr    L
# 4                 5         2     mexicana_m         1      mexicana    M
#
#    price                       name category  \
# 0  13.25         The Hawaiian Pizza  Classic
# 1  16.00   The Classic Deluxe Pizza  Classic
# 2  18.50      The Five Cheese Pizza   Veggie
# 3  20.75  The Italian Supreme Pizza  Supreme
# 4  16.00         The Mexicana Pizza   Veggie
#
#                                          ingredients  total sale
# 0           Sliced Ham, Pineapple, Mozzarella Cheese          13
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...          16
# ...

# %%
gb = df.groupby("name").agg({"quantity" : "sum"})

gb = gb.sort_values("quantity", ascending = False)
gb
# Out:
#                                             quantity
# name
# The Classic Deluxe Pizza                        2453
# The Barbecue Chicken Pizza                      2432
# The Hawaiian Pizza                              2422
# The Pepperoni Pizza                             2418
# The Thai Chicken Pizza                          2371
# The California Chicken Pizza                    2370
# The Sicilian Pizza                              1938
# The Spicy Italian Pizza                         1924
# The Southwest Chicken Pizza                     1917
# The Big Meat Pizza                              1914
# The Four Cheese Pizza                           1902
# The Italian Supreme Pizza                       1884
# The Vegetables + Vegetables Pizza               1526
# The Mexicana Pizza                              1484
# The Napolitana Pizza                            1464
# The Prosciutto and Arugula Pizza                1457
# The Spinach and Feta Pizza                      1446
# ...

# %%
ax = sns.barplot(x = gb.index, y = gb["quantity"], data = gb, palette = "viridis")
plt.xticks(rotation=90)
sns.set({"figure.figsize" : (40,15)})
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
for index, value in enumerate(gb["quantity"]):
    ax.text(index, value, str(value), ha='center', va='bottom')
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_19656\2982132664.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = gb.index, y = gb["quantity"], data = gb, palette = "viridis")

# %% [markdown]
# # 3. hotselling pizza

# %%
gb = df.groupby("name").agg({"total sale" : "sum"})

gb = gb.sort_values("total sale", ascending = False)
gb
# Out:
#                                             total sale
# name
# The Thai Chicken Pizza                           41712
# The Barbecue Chicken Pizza                       41004
# The California Chicken Pizza                     39700
# The Classic Deluxe Pizza                         37946
# The Spicy Italian Pizza                          33628
# The Southwest Chicken Pizza                      33300
# The Italian Supreme Pizza                        32383
# The Hawaiian Pizza                               31224
# The Four Cheese Pizza                            30628
# The Sicilian Pizza                               30456
# The Pepperoni Pizza                              28979
# The Greek Pizza                                  28032
# The Mexicana Pizza                               26564
# The Five Cheese Pizza                            25411
# The Italian Capocollo Pizza                      24744
# The Pepper Salami Pizza                          24656
# ...

# %%
c = sns.barplot(x = gb.index, y = gb["total sale"], data = gb, palette = "viridis")
plt.xticks(rotation=90)
sns.set({"figure.figsize" : (20,5)})
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
gb = gb.head()

c.bar_label(c.containers[0])
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_19656\879757457.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   c = sns.barplot(x = gb.index, y = gb["total sale"], data = gb, palette = "viridis")
# [Text(0, 0, '41712')]

# %% [markdown]
#   #  The Thai Chicken Pizza is generatew more sale

# %% [markdown]
# # 4. # hotselling category

# %%
c=sns.barplot(x="category",data=df,y="total sale",estimator=sum)
plt.xticks(rotation=90)
sns.set({"figure.figsize" : (3,5)})


c.bar_label(c.containers[0])
plt.show()

# %% [markdown]
# gb = df.groupby("category").agg({"total sale" : "sum"})
#
# gb = gb.sort_values("total sale", ascending = False)
# gb.idxmax()

# %% [markdown]
# # the Classic pizza is hotselling pizza

# %% [markdown]
# # 5. busiest day of the week we are getting the most orders.

# %%
gb = orders.groupby("weekday").agg({"order_id" : "count"})

gb.sort_values("order_id", ascending = True)
gb
# Out:
#            order_id
# weekday
# Friday         3538
# Monday         2794
# Saturday       3158
# Sunday         2624
# Thursday       3239
# Tuesday        2973
# Wednesday      3024

# %%
plt.figure(figsize=(6, 6))
plt.pie(gb['order_id'], labels=gb.index, autopct='%1.2f%%', startangle=140)
plt.axis('equal')
plt.title('Pie Chart of Week_day')
plt.show()

# %% [markdown]
# # busiest day of the week is friday

# %% [markdown]
# # 6. identify the time at which we are getting high orders and the time at which we are getting the lowest orders

# %% [markdown]
# # .high orders

# %%
gb = orders.groupby("hour").agg({"order_id" : "count"})
sort=gb.sort_values("order_id", ascending = False)
sort.idxmax()
sort
# Out:
#       order_id
# hour
# 12        2520
# 13        2455
# 18        2399
# 17        2336
# 19        2009
# 16        1920
# 20        1642
# 14        1472
# 15        1468
# 11        1231
# 21        1198
# 22         663
# 23          28
# 10           8
# 9            1

# %% [markdown]
# #  peak hour is : 12 to 13

# %% [markdown]
# #  lowest orders

# %%
gb = orders.groupby("hour").agg({"order_id" : "count"})
s=gb.sort_values("order_id", ascending = False)
s.idxmin()
s
# Out:
#       order_id
# hour
# 12        2520
# 13        2455
# 18        2399
# 17        2336
# 19        2009
# 16        1920
# 20        1642
# 14        1472
# 15        1468
# 11        1231
# 21        1198
# 22         663
# 23          28
# 10           8
# 9            1

# %% [markdown]
# # lowest  hour is : 9 to 10

# %% [markdown]
# # 7.Identify at which time of the day, people are ordering more pizzas (morning/evening/afternoon/night)

# %%
def a(value):
    if value>=6 and value<12:
        return "moring_order"
    elif value>=12 and value<16:
        return "after_noon_order"
    elif value>=16 and value<20:
        return "evening_order"
    else:
        return "night_order"

orders["Day_Time"]= orders["hour"] .apply(a)
orders
# Out:
#        order_id       date                time   weekday     month  year  \
# 0             1 2015-01-01 2024-04-15 11:38:36  Thursday   January  2015
# 1             2 2015-01-01 2024-04-15 11:57:40  Thursday   January  2015
# 2             3 2015-01-01 2024-04-15 12:12:28  Thursday   January  2015
# 3             4 2015-01-01 2024-04-15 12:16:31  Thursday   January  2015
# 4             5 2015-01-01 2024-04-15 12:21:30  Thursday   January  2015
# ...         ...        ...                 ...       ...       ...   ...
# 21345     21346 2015-12-31 2024-04-15 20:51:07  Thursday  December  2015
# 21346     21347 2015-12-31 2024-04-15 21:14:37  Thursday  December  2015
# 21347     21348 2015-12-31 2024-04-15 21:23:10  Thursday  December  2015
# 21348     21349 2015-12-31 2024-04-15 22:09:54  Thursday  December  2015
# 21349     21350 2015-12-31 2024-04-15 23:02:05  Thursday  December  2015
#
#        hour          Day_Time
# 0        11      moring_order
# ...

# %%
gb = orders.groupby("Day_Time").agg({"order_id" : "count"})
gb.sort_values("order_id", ascending = False)
gb.idxmax()
# Out:
# order_id    evening_order
# dtype: object

# %% [markdown]
# # the largest amount of pizza is ordering in after_noon_order
